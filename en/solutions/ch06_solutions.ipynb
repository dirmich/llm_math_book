# %% [markdown]
# # Ch 06. From Perceptrons to MLPs — Solutions
#
# > This notebook contains rigorous solutions and reproducible checks for all five exercises.

# %% [markdown]
# ## Problem 1
#
# **Problem**: Train a perceptron on the NAND function and print its weights.
#
# ### Rigorous solution
#
# Controlled factor: **training examples and labels (fixed NAND truth table)**.  Reported metric: **learned weights, bias, and four predictions**.  Interpretation and limitation: The perceptron update changes parameters only on mistakes. NAND is linearly separable, so the finite pass converges; the exact parameters depend on presentation order.

# %%
import torch
X=torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]])
y=torch.tensor([1.,1.,1.,0.]); w=torch.zeros(2); b=torch.tensor(0.)
for _ in range(20):
 for xi,yi in zip(X,y):
  e=yi-(xi@w+b>=0).float(); w+=e*xi; b+=e
p=(X@w+b>=0).int(); print({'weights':w.tolist(),'bias':b.item(),'predictions':p.tolist()}); assert torch.equal(p,y.int())

# %% [markdown]
# ## Problem 2
#
# **Problem**: Change the number of hidden neurons to 2, 4, 8, and 16, and compare XOR training speed.
#
# ### Rigorous solution
#
# Controlled factor: **hidden width: 2, 4, 8, 16**.  Reported metric: **steps to 100% XOR accuracy and final loss**.  Interpretation and limitation: All widths receive the same XOR samples, optimizer, initialization rule, and step budget. Width affects optimization capacity, but a single tiny run is not a universal ranking.

# %%
import torch
X=torch.tensor([[0.,0.],[0.,1.],[1.,0.],[1.,1.]]); y=torch.tensor([0,1,1,0])
for h in (2,4,8,16):
 torch.manual_seed(60); m=torch.nn.Sequential(torch.nn.Linear(2,h),torch.nn.Tanh(),torch.nn.Linear(h,2)); o=torch.optim.Adam(m.parameters(),lr=.05); reached=None
 for step in range(1,401):
  loss=torch.nn.functional.cross_entropy(m(X),y); o.zero_grad(); loss.backward(); o.step()
  if reached is None and (m(X).argmax(1)==y).all(): reached=step
 print({'width':h,'steps_to_full_accuracy':reached,'final_loss':round(loss.item(),6)})

# %% [markdown]
# ## Problem 3
#
# **Problem**: In the MNIST MLP, compare accuracy with 0 hidden layers (linear classifier), 1 hidden layer, and 2 hidden layers.
#
# ### Rigorous solution
#
# Controlled factor: **number of hidden layers: 0, 1, 2**.  Reported metric: **classification accuracy on a fixed nonlinear synthetic test set**.  Interpretation and limitation: A two-moons-style analytic dataset replaces MNIST to keep the experiment offline. It tests the requested depth effect, not a claimed MNIST score.

# %%
import torch
torch.manual_seed(61); X=torch.rand(400,2)*2-1; y=((X[:,0]**2+X[:,1]**2)>.45).long(); tr=torch.arange(300); te=torch.arange(300,400)
for depth in (0,1,2):
 layers=[]; d=2
 for _ in range(depth): layers += [torch.nn.Linear(d,16),torch.nn.ReLU()]; d=16
 layers += [torch.nn.Linear(d,2)]; m=torch.nn.Sequential(*layers); o=torch.optim.Adam(m.parameters(),lr=.03)
 for _ in range(150):
  loss=torch.nn.functional.cross_entropy(m(X[tr]),y[tr]); o.zero_grad(); loss.backward(); o.step()
 print({'hidden_layers':depth,'test_accuracy':round((m(X[te]).argmax(1)==y[te]).float().mean().item(),3)})

# %% [markdown]
# ## Problem 4
#
# **Problem**: Experiment with how MNIST training changes when sigmoid is used instead of ReLU.
#
# ### Rigorous solution
#
# Controlled factor: **activation: ReLU versus sigmoid**.  Reported metric: **final loss and first-layer gradient norm**.  Interpretation and limitation: Matched initial weights and data isolate the activation. Sigmoid saturation can shrink gradients; this reduced synthetic task demonstrates the mechanism rather than fabricating MNIST results.

# %%
import torch
torch.manual_seed(62); X=torch.randn(128,16)*3; y=(X[:,:3].sum(1)>0).long(); base=torch.nn.Linear(16,32); out=torch.nn.Linear(32,2)
for name,act in [('relu',torch.relu),('sigmoid',torch.sigmoid)]:
 h=torch.nn.Linear(16,32); q=torch.nn.Linear(32,2); h.load_state_dict(base.state_dict()); q.load_state_dict(out.state_dict()); o=torch.optim.SGD([*h.parameters(),*q.parameters()],lr=.1)
 for _ in range(60): loss=torch.nn.functional.cross_entropy(q(act(h(X))),y); o.zero_grad(); loss.backward(); o.step()
 print({'activation':name,'loss':round(loss.item(),5),'first_layer_grad_norm':round(h.weight.grad.norm().item(),5)})

# %% [markdown]
# ## Problem 5
#
# **Problem**: Explain intuitively why the universal approximation theorem says one hidden layer is enough.
#
# ### Rigorous solution
#
# Controlled factor: **number of localized ReLU hinge units**.  Reported metric: **maximum approximation error for |x|**.  Interpretation and limitation: A one-hidden-layer ReLU network represents a piecewise-linear function by summing hinges: |x| = ReLU(x)+ReLU(-x). Width, not additional depth, supplies more breakpoints; this illustrates the theorem but is not its full proof.

# %%
import torch
x=torch.linspace(-2,2,401); approx=torch.relu(x)+torch.relu(-x); err=(approx-x.abs()).abs().max().item(); print({'hidden_units':2,'max_abs_error':err}); assert err==0
